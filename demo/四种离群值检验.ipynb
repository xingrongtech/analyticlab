# %%
from analyticlab import twoitems, outlier
from analyticlab.numitem import NumItem
Al = NumItem('13.52 13.56 13.55 13.54 13.12 13.54 13.58 13.53 13.74 13.56 13.51', sym='m', unit='g')
outlier.Dixon(Al, process=True).show()
# Out:
# $$\begin{align}&\text{将测量数据由小到大排序：}[13.12, 13.51, 13.52, 13.53, 13.54, 13.54, 13.55, 13.56, 13.56, 13.58, 13.74]\\&\text{共有}11\text{个观测值（}n=11\text{），使用}\\&D_{11}=r_{21}=\frac{{m}_{(11)}-{m}_{(9)}}{{m}_{(11)}-{m}_{(2)}}=\frac{13.74-13.56}{13.74-13.51}=0.783\\&D_{11}'=r_{21}'=\frac{{m}_{(3)}-{m}_{(1)}}{{m}_{(10)}-{m}_{(1)}}=\frac{13.52-13.12}{13.58-13.12}=0.870\\&\text{确定检出水平}\alpha=0.05\text{，查表得临界值}\tilde{D}_{1-\alpha}(n)=\tilde{D}_{0.95}(11)=0.619\\&\text{因}D_{11}'> D_{11}\text{且}D_{11}'>\tilde{D}_{0.95}(11)\text{，故判定}{m}_{(1)}\text{为离群值}\\&\text{对于检出的离群值}{m}_{(11)}\text{，确定剔除水平}\alpha^{*}=0.01\text{，查表得临界值}\tilde{D}_{1-\alpha^{*}}(n)=\tilde{D}_{0.99}(11)=0.709\\&\text{因}D_{11}'>\tilde{D}_{0.99}(11)\text{，故判定}{m}_{(1)}=13.12\text{为统计离群值}\\&\text{取出这个观测值之后，余下的数据为}[13.51, 13.52, 13.53, 13.54, 13.54, 13.55, 13.56, 13.56, 13.58, 13.74]\\&\text{对于剩余的}10\text{个值（}n=10\text{），使用}\\&D_{10}=r_{11}=\frac{{m}_{(10)}-{m}_{(9)}}{{m}_{(10)}-{m}_{(2)}}=\frac{13.74-13.58}{13.74-13.52}=0.727\\&D_{1
# ...

# %%
Al = NumItem('13.52 13.56 13.55 13.54 13.12 13.54', sym = 'm_{4}', unit='g')
outlier.Grubbs(Al, process=True).show()
# Out:
# $$\begin{align}&\text{将测量数据由小到大排序：}[13.12, 13.52, 13.54, 13.54, 13.55, 13.56]\\&\overline{{{m_{4}}}}=\frac{1}{n}\sum\limits_{i=1}^n {{m_{4}}}_{i}=\frac{1}{6}\left(13.12+13.52+13.54+13.54+13.55+13.56\right)=13.47\\&s_{{{m_{4}}}}=\sqrt{\frac{1}{n-1}\sum\limits_{i=1}^n\left({{m_{4}}}_{i}-\overline{{{m_{4}}}}\right)^{2}}=\sqrt{\frac{1}{5}\left[\left(-0.35\right)^{2}+0.05^{2}+0.07^{2}+0.07^{2}+0.08^{2}+0.09^{2}\right]}=0.173\\&G_{6}=\frac{{m_{4}}_{(6)}-\overline{{m_{4}}}}{s}=\frac{13.56-13.47}{0.173}=0.521\\&G_{6}'=\frac{\overline{{m_{4}}}-{m_{4}}_{(1)}}{s}=\frac{13.47-13.12}{0.173}=2.025\\&\text{确定检验水平}\alpha=0.05\text{，查表得临界值}G_{1-\alpha/2}(n)=G_{0.975}(6)=1.887\\&\text{因}G_{6}'> G_{6}\text{且}G_{6}'>G_{0.975}(6)\text{，故判定}{m_{4}}_{(1)}\text{为离群值}\\&\text{对于检出的离群值}{m_{4}}_{(1)}\text{，确定剔除水平}\alpha^{*}=0.01\text{，查表得临界值}G_{1-\alpha^{*}/2}(n)=G_{0.975}(6)=1.973\\&\text{因}G_{6}'>G_{0.975}(6)\text{，故判定}{m_{4}}_{(1)}=13.12\text{为统计离群值}\end{align}$$

# %%
Al = NumItem("3.13 3.49 4.01 4.48 4.61 4.76 4.98 5.25 5.32 5.39 5.42 5.57 5.59 5.59 5.63 5.63 5.65 5.66 5.67 5.69 5.71 6.00 6.03 6.12 6.76")
outlier.Nair(Al, 0.65, side='down', process=True).show()
# Out:
# $$\begin{align}&\text{将测量数据由小到大排序：}[3.13, 3.49, 4.01, 4.48, 4.61, 4.76, 4.98, 5.25, 5.32, 5.39, 5.42, 5.57, 5.59, 5.59, 5.63, 5.63, 5.65, 5.66, 5.67, 5.69, 5.71, 6.00, 6.03, 6.12, 6.76]\\&\text{共有}25\text{个观测值（}n=25\text{），求其样本均值}\\&\overline{{{{x}}}}=\frac{1}{n}\sum\limits_{i=1}^n {{{x}}}_{i}=\frac{1}{25}\left(3.13+3.49+4.01+4.48+4.61+4.76+4.98+5.25+5.32+5.39+5.42+5.57+5.59+5.59+5.63+5.63+5.65+5.66+5.67+5.69+5.71+6.00+6.03+6.12+6.76\right)=5.29\\&\text{使用}\\&R'_{25}=\frac{\overline{{{x}}}-{{x}}_{(1)}}{\sigma}=\frac{5.29-3.13}{0.65}=3.323\\&\text{确定检出水平}\alpha=0.05\text{，查表得临界值}R_{1-\alpha}(n)=R_{0.95}(25)=2.815\\&\text{因}R_{25}'>R_{0.95}(25)\text{，故判定}{{x}}_{(1)}\text{为离群值}\\&\text{对于检出的离群值}{{x}}_{(25)}\text{，确定剔除水平}\alpha^{*}=0.01\text{，查表得临界值}R_{1-\alpha^{*}}(n)=R_{0.99}(25)=3.284\\&\text{因}R_{25}'>R_{0.99}(25)\text{，故判定}{{x}}_{(1)}=3.13\text{为统计离群值}\\&\text{取出这个观测值之后，余下的数据为}[3.49, 4.01, 4.48, 4.61, 4.76, 4.98, 5.25, 5.32, 5.39, 5.42, 5.57, 5.59, 5.59, 5.63, 5.63, 5.65, 5.66, 5.67
# ...

# %%
Al = NumItem('13.52 13.56 13.55 13.54 13.12 13.54 13.58 13.53 13.64 13.56 13.51', sym='d')
outlier.SkewKuri(Al, process=True).show()
# Out:
# $$\begin{align}&\text{将测量数据由小到大排序：}[13.12, 13.51, 13.52, 13.53, 13.54, 13.54, 13.55, 13.56, 13.56, 13.58, 13.64]\\&\text{共有}11\text{个观测值（}n=11\text{），求其样本均值}\\&\overline{{{d}}}=\frac{1}{n}\sum\limits_{i=1}^n {{d}}_{i}=\frac{1}{11}\left(13.12+13.51+13.52+13.53+13.54+13.54+13.55+13.56+13.56+13.58+13.64\right)=13.51\\&\text{使用}\\&b_{k}=\frac{n\sum\limits_{i=1}^n \left({d}_{i}-\overline{{d}}\right)^{4}}{\left[\sum\limits_{i=1}^n \left({d}_{i}-\overline{{d}}\right)^{2}\right]^{2}}=\frac{11\times\left[\left(-0.39\right)^{4}+0.00^{4}+0.01^{4}+0.02^{4}+0.03^{4}+0.03^{4}+0.04^{4}+0.05^{4}+0.05^{4}+0.07^{4}+0.13^{4}\right]}{\left[\left(-0.39\right)^{2}+0.00^{2}+0.01^{2}+0.02^{2}+0.03^{2}+0.03^{2}+0.04^{2}+0.05^{2}+0.05^{2}+0.07^{2}+0.13^{2}\right]^{2}}=7.72\\&\text{确定检出水平}\alpha=0.05\text{，查表得临界值}b'_{1-\alpha}(n)=b'_{0.95}(11)=4.02\\&\text{因}b_{k}>b'_{0.95}(11)\text{，故判定距离均值}13.51\text{最远的值}{d}_{(1)}=13.12\text{为离群值}\\&\text{对于检出的离群值}{d}_{(11)}\text{，确定剔除水平}\alpha^{*}=0.01\text{，查表得临界值}b'_{1-\
# ...
